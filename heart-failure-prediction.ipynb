# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('heart.csv')
#dict(zip(df.columns,df.loc[0]))
#df = df.append(dict(zip(df.columns,df.loc[0])),ignore_index= True)
#df.drop(918,axis=0)
#df.iloc[917] = [x for x in range(12)]
#df['Age'][917] = 'Mahendra'
df['Age'][917] = 'Mahendra'
df
# Out:
# <ipython-input-25-d311506ada9d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'][917] = 'Mahendra'
#           Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0          40   M           ATA        140          289          0     Normal
# 1          49   F           NAP        160          180          0     Normal
# 2          37   M           ATA        130          283          0         ST
# 3          48   F           ASY        138          214          0     Normal
# 4          54   M           NAP        150          195          0     Normal
# ..        ...  ..           ...        ...          ...        ...        ...
# 913        45   M            TA        110          264          0     Normal
# ...

# %%
df[]
# Out:
# 17     F
# 20     F
# 34     F
# 44     M
# 61     F
# 88     M
# 96     M
# 136    F
# 139    M
# 147    F
# 175    M
# 243    F
# 340    M
# 351    M
# 382    M
# 514    M
# 637    M
# 779    M
# 800    M
# 827    F
# 842    F
# 852    M
# 874    M
# 887    M
# Name: Sex, dtype: object

# %%
df['Sex'][df['Age']=='Mahendra']
# Out:
# 917    M
# Name: Sex, dtype: object

# %%
df[df['Age'] == 40]['Cholesterol'] #does not work with > or <
# Out:
# 0      289
# 24     215
# 102    392
# 103    466
# 152    275
# 171    235
# 231    281
# 333      0
# 457      0
# 507    240
# 634    199
# 655    223
# 762    167
# Name: Cholesterol, dtype: int64

# %%
#index = df[df['Age'] == 'Mahendra'].index 
#f.iloc[index,4]
# Out:
# 917    175
# Name: Cholesterol, dtype: int64

# %%
df[df['Age']>70].index
df2 = df.drop(df[df['Age'] > 40].index)
dict(zip(df.columns,df.iloc[0]))
# Out:
# {'Age': 40,
#  'Sex': 'M',
#  'ChestPainType': 'ATA',
#  'RestingBP': 140,
#  'Cholesterol': 289,
#  'FastingBS': 0,
#  'RestingECG': 'Normal',
#  'MaxHR': 172,
#  'ExerciseAngina': 'N',
#  'Oldpeak': 0.0,
#  'ST_Slope': 'Up',
#  'HeartDisease': 0}

# %% [markdown]
# # Checking multiple conditions

# %%
df[(df['Age'] == 40) | (df['Cholesterol'] > 288)]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# 24    40   M           NAP        130          215          0     Normal
# 28    53   F           ATA        113          468          0     Normal
# 30    53   M           NAP        145          518          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 875   58   F           NAP        120          340          0     Normal
# 882   56   F           ATA        140          294          0        LVH
# 895   57   M           ASY        110          335          0     Normal
# 900   58   M           ASY        114          318          0         ST
# 906   55   F           ATA        132          342          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.sample(5)
df.loc[df['Cholesterol'] == 194]
df.loc['Audi'] = [x for x in range(12)]
df.drop('Audi',axis = 0)
df.loc[df['Age'] == 72]
df.drop('Audi',axis = 0)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
correlation = df.corr()
sns.heatmap(df.corr(),cmap='rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Remove Column

# %%
df.drop('Age',axis = 1)
# Out:
#     Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0     M           ATA        140          289          0     Normal    172
# 1     F           NAP        160          180          0     Normal    156
# 2     M           ATA        130          283          0         ST     98
# 3     F           ASY        138          214          0     Normal    108
# 4     M           NAP        150          195          0     Normal    122
# ..   ..           ...        ...          ...        ...        ...    ...
# 913   M            TA        110          264          0     Normal    132
# 914   M           ASY        144          193          1     Normal    141
# 915   M           ASY        130          131          0     Normal    115
# 916   F           ATA        130          236          0        LVH    174
# 917   M           NAP        138          175          0     Normal    173
#
#     ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # Remove Row

# %%
df.drop(917)
df.drop(df.index[df['Sex'] == 'M'])
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 6     45   F           ATA        130          237          0     Normal
# 9     48   F           ATA        120          284          0     Normal
# 10    37   F           NAP        130          211          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 901   58   F           ASY        170          225          1        LVH
# 906   55   F           ATA        132          342          0     Normal
# 909   63   F           ASY        124          197          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# # Add Row

# %%
#df.append(dictionary)
df.iloc[916] = [x for x in range(12)]
df.loc[21321] = [x for x in range(12)]
df
# Out:
# 'N'

# %%
def heart(x):
    if x == 1 :
        return 'Yes'
    else :
        return 'No'
df['HeartDisease S'] = df['HeartDisease'].apply(heart)

# %%
df['ChestPainType'].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
df['RestingECG'].value_counts()
# Out:
# Normal    552
# LVH       188
# ST        178
# Name: RestingECG, dtype: int64

# %%
len(df.columns)
# Out:
# 12

# %%
df.loc[len(df)] = [x for x in range(12)]

# %%
df = df.drop(df.index[df['Age'] == 0],axis = 0 )

# %%
row = dict(zip(df.columns,df.loc[0]))

# %%
row1 = {}
for x in range(len(df.columns)) :
    row1.update({df.columns[x]:df.loc[0][x]})
row1
# Out:
# {'Age': 40,
#  'Sex': 'M',
#  'ChestPainType': 'ATA',
#  'RestingBP': 140,
#  'Cholesterol': 289,
#  'FastingBS': 0,
#  'RestingECG': 'Normal',
#  'MaxHR': 172,
#  'ExerciseAngina': 'N',
#  'Oldpeak': 0.0,
#  'ST_Slope': 'Up',
#  'HeartDisease': 0}

# %%
dict(zip(df.columns,df.loc[0]))
# Out:
# {'Age': 40,
#  'Sex': 'M',
#  'ChestPainType': 'ATA',
#  'RestingBP': 140,
#  'Cholesterol': 289,
#  'FastingBS': 0,
#  'RestingECG': 'Normal',
#  'MaxHR': 172,
#  'ExerciseAngina': 'N',
#  'Oldpeak': 0.0,
#  'ST_Slope': 'Up',
#  'HeartDisease': 0}

# %%
df.append(row,ignore_index=True)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
# 918   40   M           ATA        140          289          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  919.000000  919.000000   919.000000  919.000000  919.000000
# mean    53.452666  132.255713   198.587595    0.238303  136.668118
# std      9.591305   18.989990   109.513236    0.451108   25.804227
# min      0.000000    0.000000     0.000000    0.000000    7.000000
# 25%     47.000000  120.000000   173.000000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    5.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  919.000000    919.000000
# mean     0.896192      0.564744
# std      1.099067      0.604898
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      9.000000     11.000000

# %%
len(df)
# Out:
# 918

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
col = list(df.columns)
for x in col:
    print(x)
type(df['Sex'][0])
# Out:
# Age
# Sex
# ChestPainType
# RestingBP
# Cholesterol
# FastingBS
# RestingECG
# MaxHR
# ExerciseAngina
# Oldpeak
# ST_Slope
# HeartDisease
# str

# %%
col = list(df.columns)
categorical_features = []
numerical_features = []
for x in col:
    if type(df[x][0]) == str :
        categorical_features.append(x)
    else:
        numerical_features.append(x)

print('Categorical Features :',categorical_features)
print('Numerical Features :',numerical_features)
# Out:
# Categorical Features : ['Sex', 'ChestPainType', 'RestingECG', 'ExerciseAngina', 'ST_Slope']
# Numerical Features : ['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak', 'HeartDisease']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df1 = df.copy(deep = True)

df1['Sex'] = le.fit_transform(df1['Sex'])
df1['ChestPainType'] = le.fit_transform(df1['ChestPainType'])
df1['RestingECG'] = le.fit_transform(df1['RestingECG'])
df1['ExerciseAngina'] = le.fit_transform(df1['ExerciseAngina'])
df1['ST_Slope'] = le.fit_transform(df1['ST_Slope'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int32
#  2   ChestPainType   918 non-null    int32
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int32
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int32
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int32
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int32(5), int64(6)
# memory usage: 68.3 KB

# %%
df.isna().value_counts()
# Out:
# Age    Sex    ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# False  False  False          False      False        False      False       False  False           False    False     False           918
# dtype: int64

# %% [markdown]
# # Selecting specific columns

# %%
from sklearn.model_selection import train_test_split
forest = RandomForestClassifier()
cols = list(df.columns)
#X = df1.iloc[:,:-1]
X = df1.drop('HeartDisease',axis = 1)
Y = df1['HeartDisease']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,shuffle=True)

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest.fit(X_train,Y_train)
forest.predict(X_test)
preds = forest.predict(X_test)

def trainer(model):
    model.fit(X_train,Y_train)
    score = model.score(X_test,Y_test)
    preds = model.predict(X_test)
    correct = (model.predict(X_test) == Y_test).value_counts()[1]
    wrong = (model.predict(X_test) == Y_test).value_counts()[0]
    print(f'Accuracy = {score*100}%\nCorrect Predictions = {correct}\nWrong Predictions = {wrong}')

trainer(forest)
# Out:
# Accuracy = 86.95652173913044%
# Correct Predictions = 160
# Wrong Predictions = 24

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(classification_report(Y_test,forest.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84        75
#            1       0.87      0.93      0.90       109
#
#     accuracy                           0.88       184
#    macro avg       0.88      0.86      0.87       184
# weighted avg       0.88      0.88      0.87       184

# %%
confusion = confusion_matrix(Y_test,forest.predict(X_test))
pd.DataFrame(data = confusion,columns = ['True Pr','False Pr'],index = ['True A','False A'])
# Out:
#          True Pr  False Pr
# True A        60        15
# False A        8       101

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
trainer(log)
print(classification_report(Y_test,log.predict(X_test)))
# Out:
# Accuracy = 86.41304347826086%
# Correct Predictions = 159
# Wrong Predictions = 25
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85        81
#            1       0.89      0.86      0.88       103
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.87      0.86      0.86       184
# E:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # K Nearest Neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
trainer(knn)
# Out:
# Accuracy = 76.08695652173914%
# Correct Predictions = 140
# Wrong Predictions = 44

# %%
print(classification_report(Y_test,knn.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        81
#            1       0.78      0.81      0.79       103
#
#     accuracy                           0.76       184
#    macro avg       0.76      0.75      0.76       184
# weighted avg       0.76      0.76      0.76       184

# %% [markdown]
# # Summary

# %%
print(f'Random Forest Classifier\nAccuracy = {forest.score(X_test,Y_test)}')
# Out:
# Random Forest Classifier
# Accuracy = 0.8695652173913043

# %%
print(f'Logistic Regressor\nAccuracy = {log.score(X_test,Y_test)}')
# Out:
# Logistic Regressor
# Accuracy = 0.8641304347826086

# %%
print(f'K Nearest Neighbours Classifier\nAccuracy = {knn.score(X_test,Y_test)}')
# Out:
# K Nearest Neighbours Classifier
# Accuracy = 0.7608695652173914
